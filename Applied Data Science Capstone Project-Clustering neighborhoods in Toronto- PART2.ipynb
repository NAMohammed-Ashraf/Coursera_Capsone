# %% [markdown]
# PART 2 : Get the latitude and the longitude coordinates of each neighborhood

# %%
#Geocoder Python package is not used as it may be unrelieable as per the note
#Using csv file that has the geographical coordinates of each postal code

# %%
import pandas as pd

# read csv file from the address
Geospacial_Coordinates = pd.read_csv('http://cocl.us/Geospatial_data', sep = ',') 
# examine the shape of original input data

Geospacial_Coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df4 = pd.read_csv ('part1.csv') #import the dataframe from part1 of the project
df_final = pd.concat([df4, Geospacial_Coordinates], axis=1)

# %%
df_final
# Out:
#     Postcode      Borough                                       Neighborhood  \
# 0        M1B  Scarborough                                     Malvern, Rouge
# 1        M1C  Scarborough             Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# ..       ...          ...                                                ...
# 98       M9N         York                                             Weston
# 99       M9P    Etobicoke                                          Westmount
# 100      M9R    Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 101      M9V    Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 102      M9W    Etobicoke                Northwest, West Humber - Clairville
#
#     Postal Code   Latitude  Longitude
# ...

# %%
df_final .head()
# Out:
#   Postcode      Borough                            Neighborhood Postal Code  \
# 0      M1B  Scarborough                          Malvern, Rouge         M1B
# 1      M1C  Scarborough  Rouge Hill, Port Union, Highland Creek         M1C
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill         M1E
# 3      M1G  Scarborough                                  Woburn         M1G
# 4      M1H  Scarborough                               Cedarbrae         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
df_final.to_csv('df_finaldata.csv')
